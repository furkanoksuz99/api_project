# %%
import time
import re
from datetime import datetime
from bs4 import BeautifulSoup
import requests

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

from supabase import create_client

SUPABASE_URL = "https://hjgqulghdqxguwasuxiq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImhqZ3F1bGdoZHF4Z3V3YXN1eGlxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTIzMDUzMjEsImV4cCI6MjA2Nzg4MTMyMX0.dWOEfH2ymRdSpDogjXFBNFsmHPOv4gbNR3i_XIRUsBc"

supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

def normalize_text(text):
    if not text:
        return ""
    text = text.lower().strip()
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"[^\w\s]", "", text)
    return text

def etkinlik_var_mi(ticket_url, title, event_date):
    if ticket_url:
        res = supabase.table("events").select("id").eq("ticket_url", ticket_url).execute()
        if res.data:
            return True

    normalized_title = normalize_text(title)
    res = supabase.table("events").select("id, title").eq("event_date", event_date).execute()
    for item in res.data:
        if normalize_text(item["title"]) == normalized_title:
            return True
    return False

def kaydet_etkinlik(etkinlik):
    if etkinlik_var_mi(etkinlik.get('ticket_url'), etkinlik['title'], etkinlik['event_date']):
        print(f"[Atlandı] Zaten var: {etkinlik['title']} - {etkinlik['event_date']}")
        return False
    result = supabase.table("events").insert(etkinlik).execute()
    if result.data:
        print(f"[Kaydedildi] {etkinlik['title']} - {etkinlik['event_date']}")
        return True
    else:
        print(f"[Hata] Kaydedilemedi: {etkinlik['title']}")
        return False

def temizle(text):
    return text.strip() if text else "Belirtilmemiş"

def scraper_bubilet():
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

    sehirler = [
        "https://www.bubilet.com.tr/istanbul",
        "https://www.bubilet.com.tr/ankara",
        "https://www.bubilet.com.tr/izmir",
        "https://www.bubilet.com.tr/antalya",
        "https://www.bubilet.com.tr/eskişehir",
        "https://www.bubilet.com.tr/adana",
        "https://www.bubilet.com.tr/bursa",
        "https://www.bubilet.com.tr/gaziantep",
        "https://www.bubilet.com.tr/mersin",
        
    ]
    etkinlikler = []

    for url in sehirler:
        sehir = url.split("/")[-1].capitalize()
        print(f"[BUBİLET] {sehir} veri çekiliyor...")
        driver.get(url)
        time.sleep(5)

        try:
            buton = driver.find_element(By.XPATH, "//button[contains(text(), 'Bugün')]")
            driver.execute_script("arguments[0].click();", buton)
            time.sleep(3)
        except:
            pass

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(1)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        soup = BeautifulSoup(driver.page_source, "html.parser")
        event_divs = soup.find_all("div", class_="px-1 pt-2")

        for div in event_divs:
            a_tag = div.find_parent("a")
            ticket_url = "https://www.bubilet.com.tr" + a_tag["href"] if a_tag else None

            title = div.find("h3").get_text(strip=True) if div.find("h3") else "Belirtilmemiş"
            p_tags = div.find_all("p", class_="text-gray-500")
            venue = p_tags[0].get_text(strip=True) if len(p_tags) > 0 else "Belirtilmemiş"

            # Fiyat bilgisi
            price_span = div.find("span", class_="tracking-tight")
            try:
                price_text = price_span.get_text(strip=True) if price_span else None
                price_value = int(re.sub(r"[^\d]", "", price_text)) if price_text else None
            except:
                price_value = None

            etkinlik = {
                "title": temizle(title),
                "venue": temizle(venue),
                "event_date": datetime.now().isoformat(),
                "city": sehir,
                "ticket_url": ticket_url,
                "price_min": price_value,
                "price_max": price_value,
                "is_free": price_value == 0 if price_value is not None else False,
                "organizer": None,
                "image_url": None,
                "category": None,
                "description": None,
                "tags": None,
            }
            etkinlikler.append(etkinlik)

    driver.quit()
    print(f"[BUBİLET] Toplam {len(etkinlikler)} etkinlik bulundu.")
    return etkinlikler

def scraper_mobilet():
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--no-sandbox")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

    url = "https://mobilet.com/tr/search/?dates=-1"
    driver.get(url)
    time.sleep(3)

    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        try:
            buttons = driver.find_elements(By.TAG_NAME, "button")
            clicked = False
            for btn in buttons:
                if "Daha Fazlası" in btn.text and btn.is_displayed():
                    btn.click()
                    time.sleep(3)
                    clicked = True
                    break
            if not clicked:
                break
        except Exception:
            time.sleep(2)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    driver.quit()

    etkinlikler = []
    cards = soup.find_all("div", class_="AgendaSectionstyle__EventCardContainer-sc-itltr4-3")
    for card in cards:
        title_tag = card.find("h3", class_="EventCardstyles__EventTitle-sc-bsxxjx-6")
        title = title_tag.get_text(strip=True) if title_tag else "Belirtilmemiş"

        venue_tags = card.find_all("p", class_="EventCardstyles__EventInfoText-sc-bsxxjx-9")
        venue = venue_tags[1].get_text(strip=True) if len(venue_tags) > 1 else "Belirtilmemiş"

        link_tag = card.find("a", href=True)
        ticket_url = "https://mobilet.com" + link_tag["href"] if link_tag else None

        etkinlik = {
            "title": temizle(title),
            "venue": temizle(venue),
            "event_date": datetime.now().isoformat(),
            "city": None,
            "ticket_url": ticket_url,
            "price_min": None,
            "price_max": None,
            "is_free": False,
            "organizer": None,
            "image_url": None,
            "category": None,
            "description": None,
            "tags": None,
        }
        etkinlikler.append(etkinlik)

    print(f"[MOBILET] Toplam {len(etkinlikler)} etkinlik bulundu.")
    return etkinlikler

def scraper_biletinial():
    etkinlikler = []
    headers = {"User-Agent": "Mozilla/5.0"}

    urls = [
        "https://biletinial.com/tr-tr/tiyatro",
        "https://biletinial.com/tr-tr/muzik",
        "https://biletinial.com/tr-tr/sinema",
    ]

    for url in urls:
        r = requests.get(url, headers=headers)
        soup = BeautifulSoup(r.content, "html.parser")

        for li in soup.find_all("li"):
            h3 = li.find("h3")
            if not h3:
                continue
            a_tag = h3.find("a", href=True)
            if not a_tag:
                continue

            title = a_tag.get_text(strip=True)
            link = "https://biletinial.com" + a_tag.get("href")

            address = li.find("address")
            mekan = address.find("small").get_text(strip=True) if address and address.find("small") else "Belirtilmemiş"
            city = address.find("b").get_text(strip=True) if address and address.find("b") else None

            etkinlik = {
                "title": temizle(title),
                "venue": temizle(mekan),
                "event_date": datetime.now().isoformat(),
                "city": city,
                "ticket_url": link,
                "price_min": None,
                "price_max": None,
                "is_free": False,
                "organizer": None,
                "image_url": None,
                "category": None,
                "description": None,
                "tags": None,
            }
            etkinlikler.append(etkinlik)

    print(f"[BILETINIAL] Toplam {len(etkinlikler)} etkinlik bulundu.")
    return etkinlikler



def main():
    print("Etkinlik toplayıcı başladı...")
    bubilet_events = scraper_bubilet()
    mobilet_events = scraper_mobilet()
    biletinial_events = scraper_biletinial()

    tum_etkinlikler = bubilet_events + mobilet_events + biletinial_events
    print(f"Toplam {len(tum_etkinlikler)} bugünün etkinliği bulundu.")

    kaydedilen = 0
    atlanan = 0
    for etkinlik in tum_etkinlikler:
        if kaydet_etkinlik(etkinlik):
            kaydedilen += 1
        else:
            atlanan += 1

    print(f"Kaydedilen etkinlik sayısı: {kaydedilen}")
    print(f"Atlanan (tekrar) etkinlik sayısı: {atlanan}")
    print("İşlem tamamlandı.")

if __name__ == "__main__":
    main()
# Out:
# Etkinlik toplayıcı başladı...
# [BUBİLET] Istanbul veri çekiliyor...
# [BUBİLET] Ankara veri çekiliyor...
# [BUBİLET] Izmir veri çekiliyor...
# [BUBİLET] Antalya veri çekiliyor...
# [BUBİLET] Eskişehir veri çekiliyor...
# [BUBİLET] Adana veri çekiliyor...
# [BUBİLET] Bursa veri çekiliyor...
# [BUBİLET] Gaziantep veri çekiliyor...
# [BUBİLET] Mersin veri çekiliyor...
# [BUBİLET] Toplam 89 etkinlik bulundu.
# [MOBILET] Toplam 17 etkinlik bulundu.
# [BILETINIAL] Toplam 183 etkinlik bulundu.
# Toplam 289 bugünün etkinliği bulundu.
# [Kaydedildi] Tahsin Hasoğlu - 2025-07-16T11:17:45.753483
# [Kaydedildi] The HU - 2025-07-16T11:17:45.753483
# [Kaydedildi] Kenan Doğulu - 2025-07-16T11:17:45.753483
# [Atlandı] Zaten var: Mekanda Sanat Var: Heykel ve Resim Workshopları | Anadolu Yakası - 2025-07-16T11:17:45.753483
# [Kaydedildi] BKM Mutfak +1 Stand Up Gecesi - 2025-07-16T11:17:45.753483
# [Kaydedildi] Yetenek Sizsiniz Sezon Açılışı - 2025-07-16T11:17:45.754485
# [Atlandı] Zaten var: Bu Gece Boğazdayız - 2025-07-16T11:17:45.754485
# [Kaydedildi] Fatma Hasçelik - 2025-07-16T11:17:45.754485
# [Atlandı] Zaten var: Mekanda Sanat Var: Heykel ve Resim Workshopları | Avrupa Yakası - 2025-07-16T11:17:45.754485
# [Atlandı] Zaten var: Piramitlere Yolculuk - Antik Mısır'ın Keşfi - 2025-07-16T11:17:45.754485
# [Kaydedildi] Avatar The Last Airbender Quiz Night - 2025-07-16T11:17:45.754485
# [Kaydedildi] Kendimden Hallice Konseri - 2025-07-16T11:17:45.754485
# [Atlandı] Zaten var: Buz Adası - 2025-07-16T11:17:45.754485
# [Kaydedildi] Legends of Istanbul - 2025-07-16T11:17:45.754485
# [Atlandı] Zaten var: Son Kale-Orta Çağ'ın Keşfi - 2025-07-16T11:17:45.754485
# [Kaydedildi] 90'lar Türkçe Pop - 2025-07-16T11:17:45.755489
# [Kaydedildi] Stand up Taksim Gecesi + Açık Mikrofon - 2025-07-16T11:17:45.755489
# [Kaydedildi] DJ Sercan Umut ile Geçmişten Günümüze 90'lar 2000'ler Türkçe Pop - 2025-07-16T11:17:45.755489
# [Atlandı] Zaten var: Highlights in Türkiye Workshop | Parfüm Yapım Atölyesi - 2025-07-16T11:17:45.755489
# [Atlandı] Zaten var: Studio Masterpiece - 2025-07-16T11:17:45.755489
# [Atlandı] Zaten var: Emaar Akvaryum & Sualtı Hayvanat Bahçesi - 2025-07-16T11:17:45.755489
# [Kaydedildi] Boğaziçi Komedi Kulübü - Kadıköy Stand-up Gecesi - 2025-07-16T11:17:45.755489
# [Kaydedildi] AÇIK MİKROFON EXTRA Stand up Gecesi Taksim- Pera- Beyoğlu - 2025-07-16T11:17:45.755489
# [Atlandı] Zaten var: Açık Mikrofon Stand Up Komedi @Beşiktaş - 2025-07-16T11:17:45.756489
# [Atlandı] Zaten var: Emaar SkyView ve SkyWalk - 2025-07-16T11:17:45.756489
# [Kaydedildi] Oğuz Atay - 2025-07-16T11:17:45.756489
# [Atlandı] Zaten var: Highlights in Türkiye Workshop | Ebru Atölyesi - 2025-07-16T11:17:45.756489
# [Atlandı] Zaten var: Highlights in Türkiye Workshop | Dünya Çayları ve Türk Çayı Demleme Atölyesi - 2025-07-16T11:17:45.756489
# [Kaydedildi] Highlights in Türkiye Workshop | Dünya Mutfağı ve Yemek Stilistliği Atölyesi - 2025-07-16T11:17:45.756489
# [Atlandı] Zaten var: Highlights in Türkiye Workshop | Mozaik Lamba Atölyesi - 2025-07-16T11:17:45.756489
# [Atlandı] Zaten var: Highlights in Türkiye Workshop | Kumda Nitelikli Türk Kahvesi Atölyesi ve Kahve Falı - 2025-07-16T11:17:45.757490
# [Kaydedildi] Beyoğlu Stand up Gecesi - 2025-07-16T11:17:45.757490
# [Atlandı] Zaten var: Prenses Hamlet - 2025-07-16T11:17:45.757490
# [Kaydedildi] Bir Kadının Yaşamından Yirmi Dört Saat - 2025-07-16T11:17:45.757490
# [Kaydedildi] Anna Karenina - 2025-07-16T11:17:45.757490
# [Atlandı] Zaten var: Eser Diamond Aquapark - 2025-07-16T11:17:45.757490
# [Kaydedildi] How Many Person Presents: Ede - 2025-07-16T11:17:45.757490
# [Kaydedildi] Metin Zakoğlu ile Yemek Masası Kabaresi - 2025-07-16T11:17:45.757490
# [Kaydedildi] Workshop: Sosyal Sanathane İstanbul | Etkinlik Takvimi - 2025-07-16T11:17:45.757490
# [Kaydedildi] Cadde Stand-up Night - 2025-07-16T11:17:45.758494
# [Kaydedildi] Quiz Night: Gibi - 2025-07-16T11:17:45.758494
# [Kaydedildi] Taha Ercoşkun - Politik Stand Up - 2025-07-16T11:17:45.758494
# [Kaydedildi] Stand Up Gecesi Falan İstanbul - 2025-07-16T11:17:45.758494
# [Atlandı] Zaten var: Fabrikada Cinayet Oyunu - 2025-07-16T11:17:56.661423
# [Kaydedildi] Küçük Bir Aşk Masalı - 2025-07-16T11:17:56.661423
# [Kaydedildi] Trivia Night - 2025-07-16T11:17:56.662499
# [Kaydedildi] Bir İshaksın Bir Cemil Oyunu - 2025-07-16T11:17:56.662499
# [Kaydedildi] Gossip Girl Quiz Night - 2025-07-16T11:17:56.662499
# [Atlandı] Zaten var: Studio Masterpiece - 2025-07-16T11:17:56.662499
# [Kaydedildi] Bilim Karnavalı - 2025-07-16T11:17:56.662499
# [Kaydedildi] Açık Mikrofon Stand-up - Dükkan Komedi Kulübü - 2025-07-16T11:17:56.663726
# [Kaydedildi] Güldürgeç Doğaçlama - 2025-07-16T11:17:56.663726
# [Kaydedildi] Capital Lights - 2025-07-16T11:17:56.663726
# [Atlandı] Zaten var: Terra Point Art - Workshop - 2025-07-16T11:17:56.664730
# [Kaydedildi] Bubble Show - 2025-07-16T11:17:56.664730
# [Atlandı] Zaten var: No:24 Studio - 2025-07-16T11:17:56.664730
# [Atlandı] Zaten var: Altı Üstü Stand Up Gecesi - 2025-07-16T11:17:56.664730
# [Kaydedildi] El Açması Rozbeef Pizza - 2025-07-16T11:17:56.665761
# [Atlandı] Zaten var: Workshop: Etkinlik Takvimi | Sosyal Sanathane Ankara - 2025-07-16T11:17:56.665761
# [Kaydedildi] Lola Küba Gecesi - 2025-07-16T11:17:56.665761
# [Kaydedildi] S'Talk Show - 2025-07-16T11:17:56.666758
# [Kaydedildi] Karaoke Gecesi - 2025-07-16T11:17:56.666758
# [Kaydedildi] Mesut Süre ile İlişki Testi Filtresiz - 2025-07-16T11:18:07.533107
# [Kaydedildi] Yavuz Günal Tek Kişilik Stand Up - III. YAVUZ - 2025-07-16T11:18:07.533107
# [Kaydedildi] %100 Müzik Sunar: Cemiyette Pişiyorum, Deli Gömleği, Spray - 2025-07-16T11:18:07.533107
# [Kaydedildi] Levo’nun Tavernası - 2025-07-16T11:18:07.534228
# [Kaydedildi] İzArt - Resim ve Heykel Workshopları - İzmir - 2025-07-16T11:18:07.534228
# [Kaydedildi] Alpay Erdem - Kolsuz Tişört - Stand Up - 2025-07-16T11:18:07.534228
# [Kaydedildi] Rafet El Roman Konseri - 2025-07-16T11:18:07.534228
# [Atlandı] Zaten var: Leonart Atölye | Seramik, Resim, Heykel, Mum Workshopları - 2025-07-16T11:18:07.534228
# [Kaydedildi] Genel Kültür Quiz Night - 2025-07-16T11:18:07.534228
# [Atlandı] Zaten var: Workshop: Sanat Köşk | Etkinlikler - 2025-07-16T11:18:07.535225
# [Kaydedildi] Atölye Zesku Workshop's Yetişkin & Çocuk Resim Atölyesi Tasarım ve Çeşitli Sanatsal Etkinlikler İzmir Karşıyaka - 2025-07-16T11:18:07.535225
# [Kaydedildi] Açık Mikrofon Stand Up Gecesi - 2025-07-16T11:18:07.535225
# [Kaydedildi] Kurbiş Çocuk Haklarını Arıyor Kukla Oyunu - 2025-07-16T11:18:07.535225
# [Atlandı] Zaten var: Workshop: Nil Kitap Kafe İzmir | Etkinlik Takvimi - 2025-07-16T11:18:07.535225
# [Kaydedildi] Ata Demirer Gazinosu 2 - 2025-07-16T11:18:17.006866
# [Kaydedildi] Sergen Deveci Ketenpere / Olan Stand Up - 2025-07-16T11:18:17.007870
# [Kaydedildi] Ali Rıza Tanyeli - Kendime Düşünceler-Stand Up - 2025-07-16T11:18:17.007870
# [Kaydedildi] Mekanda Sanat Var: Heykel ve Resim Workshopları | Antalya - 2025-07-16T11:18:17.007870
# [Kaydedildi] Dj Hakan Küfündür ile 90'lar & 2000'ler Türkçe Pop Parti - 2025-07-16T11:18:17.007870
# [Kaydedildi] Highlights in Türkiye Workshop | Parfüm Yapım Atölyesi - 2025-07-16T11:18:17.007870
# [Kaydedildi] Highlights in Türkiye Workshop | Mozaik Lamba Atölyesi - 2025-07-16T11:18:17.007870
# [Kaydedildi] Highlights in Türkiye Workshop | Kumda Nitelikli Türk Kahvesi Atölyesi ve Kahve Falı - 2025-07-16T11:18:17.009055
# [Kaydedildi] Iraz Yıldız - 63. Uluslararası Bursa Festivali - 2025-07-16T11:20:31.319740
# [Kaydedildi] Bursa Stand Up Gecesi - 2025-07-16T11:20:31.319740
# [Kaydedildi] Mekanda Sanat Var: Heykel ve Resim Workshopları | Bursa - 2025-07-16T11:20:31.319740
# [Kaydedildi] DENDEN Konseri - 2025-07-16T11:20:31.319740
# [Kaydedildi] Ceren ÖZDEMİR - 2025-07-16T11:20:51.596908
# [Kaydedildi] Sandland Antalya - 2025-07-16T11:21:08.856756
# [Kaydedildi] Barış Manço Evi - 2025-07-16T11:21:08.857757
# [Kaydedildi] Yetenek Sizsiniz - 2025-07-16T11:21:08.857757
# [Kaydedildi] Yetenek Sizsiniz 2. Tur - 2025-07-16T11:21:08.857757
# [Kaydedildi] Bir Kadının Yaşamından Yirmi Dört Saat - 2025-07-16T11:21:08.857757
# [Kaydedildi] Sevgiliyle Koku - Parfüm Tasarım Workshop'u - 2025-07-16T11:21:08.857757
# [Atlandı] Zaten var: Yetenek Sizsiniz 2. Tur - 2025-07-16T11:21:08.857757
# [Kaydedildi] Anna Karenina - 2025-07-16T11:21:08.857757
# [Kaydedildi] Kadıköy Stand-up Gecesi - 2025-07-16T11:21:08.857757
# [Kaydedildi] Beyoğlu Stand Up Gecesi - 2025-07-16T11:21:08.857757
# [Kaydedildi] Prenses Hamlet - 2025-07-16T11:21:08.857757
# [Kaydedildi] Stand Up Taksim Gecesi + Açık Mikrofon - 2025-07-16T11:21:08.857757
# [Kaydedildi] Açık Mikrofon Extra - 2025-07-16T11:21:08.859078
# [Kaydedildi] Bursa Stand Up Gecesi - 2025-07-16T11:21:08.859078
# [Kaydedildi] Açık Mikrofon Stand Up Komedi @Beşiktaş - 2025-07-16T11:21:08.859078
# [Kaydedildi] Yasemin Rosa - 2025-07-16T11:21:08.859078
# [Kaydedildi] Metin Zakoğlu ile Yemek Masası Kabaresi - 2025-07-16T11:21:08.859078
# [Atlandı] Zaten var: Mesut Süre ile İlişki Testi 'Filtresiz' - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Othello - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Macbeth - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Şirreti Evcilleştirmek - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Babamı Kim Öldürdü - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Eser Yenenler ile İtiraf Et - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Aydınlıkevler - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Sevgili Arsız Ölüm Dirmit - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Doğu Demirkol - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Drakula - 2025-07-16T11:21:13.477432
# [Atlandı] Zaten var: Bir Baba Hamlet - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Cimri - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Morkomedyen Stand Up - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Richard - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Bulaşıkçılar - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Seyfi Bey - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: 39 Buçuk Basamak - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Saatleri Ayarlama Enstitüsü - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Berfu & Eser Yenenler - Çift Terapisi - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Aşkım Kapışmak - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Okan Çabalar Stand Up - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Çok Güzel Hareketler 2 - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Şakşakçılar - 2025-07-16T11:21:13.478615
# [Atlandı] Zaten var: Evlilikte Ufak Tefek Cinayetler - 2025-07-16T11:21:13.479662
# [Atlandı] Zaten var: Meksika Açmazı - 2025-07-16T11:21:13.479662
# [Atlandı] Zaten var: Ata Demirer Gazinosu 2 - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: An Epic Symphony & Özcan Deniz - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: Pinhani - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: Levent Yüksel Konseri - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: Can Ozan - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: An Epic Symphony & Mustafa Sandal - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: An Epic Symphony & Adamlar - 2025-07-16T11:21:14.019660
# [Atlandı] Zaten var: An Epic Symphony & Gökhan Türkmen - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Candan Erçetin 30. Yıl Konserleri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Cem Adrian Konseri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Serdar Ortaç Konseri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Sıla - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Melike Şahin Konseri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Justin Timberlake - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Ajda Pekkan - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Simge Konseri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: +1 Sunar: Dark Sun Metal Festival: Sepultura, Radical Noise, Helak - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Nilüfer - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Kenan Doğulu Konseri - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: Burgazada Music Festival - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: +1 Sunar: Dark Sun Metal Festival: Epica, Myrkur, Knight Errant - 2025-07-16T11:21:14.020701
# [Atlandı] Zaten var: An Epic Symphony & Hayko Cepkin - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: Gökhan Türkmen - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: PSM Loves Summer by %100 Müzik: Hurts - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: Melike Şahin - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: Melis Fis - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: Seksendört - 2025-07-16T11:21:14.021916
# [Atlandı] Zaten var: Emre Aydın - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: Mabel Matiz - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: Wardruna Konseri - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: Can Bonomo - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: +1 Sunar: Pozitif Vibrations Michael Kiwanuka - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: İbrahim Tatlıses Konseri - 2025-07-16T11:21:14.022964
# [Kaydedildi] Evgeny Grinko - 2025-07-16T11:21:14.022964
# [Atlandı] Zaten var: Superman - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Mission: Impossible - Son Hesaplaşma - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Maria - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: F1 Filmi - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Fenike Planı - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Sihirli Annem: Hepimiz Biriz - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Rafadan Tayfa: Kapadokya - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Napolyon - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Terminatör 2: Mahşer Günü - 2025-07-16T11:21:14.546386
# [Atlandı] Zaten var: Ölümcül Uçuş - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Ballerina - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Bir Minecraft Filmi - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Lilo ve Stiç - 2025-07-16T11:21:14.547384
# [Kaydedildi] Mutlu Oyuncak Dükkanı - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Aslan Hürkuş 3: Anka Adası - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Buz Devri - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Cesur Dinozor - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Caretta Bobi - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Kaptan Sabertooth: Kayıp Hazinenin Peşinde - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Yürüyen Şato - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Elli'nin Canavar Takımı - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Gerçek Ötesi - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Hiçbir Şey Normal Değil - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Sekiz Buçuk - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Acil Durumda Jane'i Ara - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Polonya Sineması: Çatıdaki Kadın / Woman on the Roof - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Sessiz Kız - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Bilinmeyen Kod - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Benny’nin Videosu - 2025-07-16T11:21:14.547384
# [Atlandı] Zaten var: Polonya Sineması: Ai / Eo - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Gülizar - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Köpekle Kurt Arasında - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Ölü Mevsim - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Yaz Işığı - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Muhteşem Lillian Hall - 2025-07-16T11:21:14.548381
# [Kaydedildi] Sil Baştan - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Ciddi Olmanın Önemi - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Savrulan Zaman - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Parmaklıklar Ardında İki Kadın - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Tesadüfi Bir Kronolojinin 71 Parçası - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: En Değerli Hediye - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Soğuk Savaş - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: İncir Reçeli - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Korsaj - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Konsey - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Dogville - 2025-07-16T11:21:14.548381
# [Kaydedildi] Toni Erdmann - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Gerçek Acı - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Cin Bebek 3 - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Çölde Çay - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Öldürdüğün Şeyler - 2025-07-16T11:21:14.548381
# [Atlandı] Zaten var: Çocuk ve Balıkçıl - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Ejderhanı Nasıl Eğitirsin - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Altına Hücum - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: 400 Darbe - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Leon: Sevginin Gücü - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Elveda Lenin - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Issız Adam - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Düşler, Tutkular & Suçlar - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Çalınmış Güzellik - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Üç Renk: Beyaz - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Sıkı Dostlar - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: On Saniye - 2025-07-16T11:21:14.549378
# [Kaydedildi] Ben Efsaneyim - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Asla Bırakma - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Testere - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: 28 Yıl Sonra - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Ölümcül Çağrı - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Megan 2.0 - 2025-07-16T11:21:14.549378
# [Kaydedildi] Geçen Yaz Ne Yaptığını Biliyorum - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Fidan - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Hep Yek: Loto - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Düğün Evi - 2025-07-16T11:21:14.549378
# [Kaydedildi] Gelenek Görenek - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Siccin 8 - 2025-07-16T11:21:14.549378
# [Atlandı] Zaten var: Zikir - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Musibet - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Üç Arkadaş - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Akıllı Tavşan Momo: Büyük Takip - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Fantastik Dörtlü: İlk Adımlar - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Diş Perisi Masalı - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Flow: Bir Kedinin Yolculuğu - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Elio - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Şirinler Filmi - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Jurassic World: Yeniden Doğuş - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Genç Werther'in Acıları - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Sonradan Gurme - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Tam Bana Göre - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Ayak Takımı - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Askıda Bilet - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Aramızdaki Gerçekler / The Truth Between Us - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Captain America: Brave New World/ Kaptan Amerika: Cesur Yeni Dünya - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Örümcek Adam Eve Dönüş Yok (2021) - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Superman - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Suicide Squad İntihar Timi - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Ruhların Kaçışı - Film Gösterimi - 2025-07-16T11:21:14.550716
# [Atlandı] Zaten var: Köpeklere veya İtalyanlara İzin Yok - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Charlie Çikolata Fabrikası - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Toy Story! - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Hey Joe - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: İddia / High Stakes - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Katil Dostum / My Killer Buddy - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Son Kez Çocuk Olduğumuzda / The Last Time We Were Children - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Müzede Suare: Eternal Sunshine Of The Spotless Mind - Sil Baştan - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Polonya Sineması: Ida - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Maria - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Aznavour - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: A Complete Unknown/ Bob Dylan: Tam Bir Bilinmez - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Conclave/Konsey - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Saykoterapi: Bir Seri Katil Hakkında Yazmaya Karar Veren Yazarın Sığ Hikayesi - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: A Real Pain/ Gerçek Acı - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: The Substance/ Cevher - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Karanlık Yollarda - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Borgo - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Polonya Sineması: Soğuk Savaş / Cold War - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: F1: The Movie /F1 Filmi - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Açık Hava Film Gösterimi: Kazara Arkadaş / Friends By Chance - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Asteriks ve Oburiks: Görevimiz Kleopatra - 2025-07-16T11:21:14.551796
# [Atlandı] Zaten var: Prenses Mononoke - 2025-07-16T11:21:14.552826
# [Atlandı] Zaten var: Kompromat - 2025-07-16T11:21:14.552826
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Materialists/Tam Bana Göre - 2025-07-16T11:21:14.552826
# [Atlandı] Zaten var: Müzede Suare: Failure To Launch - Düş Yakamızdan - 2025-07-16T11:21:14.552826
# [Atlandı] Zaten var: Müzede Suare: Mamma Mia! - 2025-07-16T11:21:14.552826
# [Atlandı] Zaten var: Tersane Açıkhava Sineması: Riff Raff/ Ayak Takımı - 2025-07-16T11:21:14.552826
# Kaydedilen etkinlik sayısı: 86
# Atlanan (tekrar) etkinlik sayısı: 203
# İşlem tamamlandı.
