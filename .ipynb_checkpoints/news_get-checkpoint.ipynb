# %%
import requests
import feedparser
from datetime import datetime
from supabase import create_client, Client
import re
from bs4 import BeautifulSoup
import time

SUPABASE_URL = "https://hjgqulghdqxguwasuxiq.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImhqZ3F1bGdoZHF4Z3V3YXN1eGlxIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTIzMDUzMjEsImV4cCI6MjA2Nzg4MTMyMX0.dWOEfH2ymRdSpDogjXFBNFsmHPOv4gbNR3i_XIRUsBc"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)


NEWS_SOURCES = {
    "haberturk": "https://www.haberturk.com/rss",
    "ntv": "https://www.ntv.com.tr/gundem.rss", 
    "bbc": "https://feeds.bbci.co.uk/turkce/rss.xml",
    "trt": "https://www.trthaber.com/sondakika_articles.rss",
    "hurriyet": "https://www.hurriyet.com.tr/rss/anasayfa",
    "sabah": "https://www.sabah.com.tr/rss/anasayfa.xml",
    "cumhuriyet": "https://www.cumhuriyet.com.tr/rss/son_dakika.xml",
    "hurriyet": "https://www.hurriyet.com.tr/rss/anasayfa",
    "sabah": "https://www.sabah.com.tr/rss/anasayfa.xml",
    "sozcu": "https://www.sozcu.com.tr/feed/",
    "cumhuriyet": "https://www.cumhuriyet.com.tr/rss/son_dakika.xml",
    "milliyet": "https://www.milliyet.com.tr/rss/rssnew/gundemrss.xml"
}

def clean_text(text):
    if not text:
        return ""
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def extract_content(url):
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
        }
        response = requests.get(url, headers=headers, timeout=10)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        content_selectors = [
            'article', '.content', '.article-content', 
            '.news-content', '.post-content', 'main'
        ]
        
        for selector in content_selectors:
            content = soup.select_one(selector)
            if content:
                return clean_text(content.get_text())
        
        return ""
    except Exception as e:
        print(f"İçerik çekme hatası: {e}")
        return ""

def scrape_news_source(source_name, rss_url):
    try:
        print(f"{source_name} kaynağından haberler çekiliyor...")
        
        # RSS feed'i parse et
        feed = feedparser.parse(rss_url)
        
        if not feed.entries:
            print(f"❌ {source_name} - RSS feed'de haber bulunamadı")
            return
        
        print(f"✓ {source_name} - {len(feed.entries)} haber bulundu")
        
        for entry in feed.entries:
            
            existing = supabase.table('news').select('id').eq('url', entry.link).execute()
            
            if existing.data:
                continue  # Zaten var, geç
            
            title = clean_text(entry.title)
            summary = clean_text(entry.get('summary', ''))
            published_date = None
            
            if hasattr(entry, 'published_parsed') and entry.published_parsed:
                published_date = datetime(*entry.published_parsed[:6]).isoformat()
            
           
            content = extract_content(entry.link)
            
   
            category = "genel"
            if any(word in title.lower() for word in ['spor', 'futbol', 'basketbol']):
                category = "spor"
            elif any(word in title.lower() for word in ['ekonomi', 'dolar', 'borsa']):
                category = "ekonomi"
            elif any(word in title.lower() for word in ['siyaset', 'seçim', 'parti']):
                category = "siyaset"
            
            news_data = {
                'title': title,
                'content': content if content else summary,
                'summary': summary,
                'url': entry.link,
                'source': source_name,
                'published_date': published_date,
                'category': category,
                'language': 'tr'
            }
            
            # Veritabanına kaydet
            result = supabase.table('news').insert(news_data).execute()
            
            if result.data:
                print(f"✓ Haber kaydedildi: {title[:50]}...")
            else:
                print(f"✗ Haber kaydedilemedi: {title[:50]}...")
            
            time.sleep(1)  # Rate limiting
            
    except Exception as e:
        print(f"❌ {source_name} scraping hatası: {e}")

def main():
    print("Haber toplama başlatılıyor...")
    
    for source_name, rss_url in NEWS_SOURCES.items():
        scrape_news_source(source_name, rss_url)
        time.sleep(2)  # Kaynaklar arası bekleme
    
    print("Haber toplama tamamlandı!")

if __name__ == "__main__":
    main()
# Out:
# Haber toplama başlatılıyor...
# haberturk kaynağından haberler çekiliyor...
# ✓ haberturk - 100 haber bulundu
# ✓ Haber kaydedildi: Adaylardan AGS yorumları...
# ✓ Haber kaydedildi: AGS-ÖABT soru ve cevap anahtarı yayınlandı mı?...
# ✓ Haber kaydedildi: Temmuz ayında temettü veren şirketler...
# ✓ Haber kaydedildi: 12 Temmuz reyting sonuçları açıklandı...
# ✓ Haber kaydedildi: Erzurum ve Manisa'da deprem oldu...
# ✓ Haber kaydedildi: Altın fiyatlarında yükseliş sürüyor...
# ✓ Haber kaydedildi: AGS-ÖABT sınav oturum saatleri...
# ✓ Haber kaydedildi: MasterChef kim kazandı?...
# ✓ Haber kaydedildi: İstanbul'da sular ne zaman gelecek?...
# ✓ Haber kaydedildi: AGS ne zaman?...
# ✓ Haber kaydedildi: Kredi kartı ve kredi borcu yapılandırma nasıl yapı...
# ✓ Haber kaydedildi: Son depremler listesi...
# ✓ Haber kaydedildi: 'Kendimi şanslı hissediyorum' butonu neden var?...
# ✓ Haber kaydedildi: Emekli promosyon kampanyaları Temmuz 2025...
# ✓ Haber kaydedildi: 3 kişinin öldüğü yangında alarm sistemi iddiası!...
# ✓ Haber kaydedildi: Ukrayna telefon kodu...
# ✓ Haber kaydedildi: Martın cooper neyi icat etti?...
# ✓ Haber kaydedildi: James watt neyi icat etti?...
# ✓ Haber kaydedildi: Güney Afrika bayrağı nedir?...
# ✓ Haber kaydedildi: Konteynerde soygun cinayeti!...
# ✓ Haber kaydedildi: Albert eınsteın neyi icat etti?...
# ✓ Haber kaydedildi: Özel ve Bahçeli'yi ziyaret edecekler...
# ✓ Haber kaydedildi: Komisyonun kurulacağı tarih netleşti...
# ✓ Haber kaydedildi: Motoryat alevlere teslim!...
# ✓ Haber kaydedildi: "Otel yönetimi, çıkarken yan odadakileri bile uyan...
# ✓ Haber kaydedildi: Epilepsi nöbeti geçirdi! 4.kattan düştü!...
# ✓ Haber kaydedildi: Şile Belediye Başkanı adliyeye sevk edildi...
# ✓ Haber kaydedildi: Muson yağmurları 104 can aldı!...
# ✓ Haber kaydedildi: "Biz barışın da demokrasinin de teminatıyız"...
# ✓ Haber kaydedildi: İkiz kardeşlere silahlı saldırı: 1 ölü, 1 yaralı...
# ✓ Haber kaydedildi: Trump'tan 'Epstein dosyaları' tepkisi...
# ✓ Haber kaydedildi: Restoranda silahlı bıçaklı kavga: 7 yaralı...
# ✓ Haber kaydedildi: Düğünde pompalı tüfekle havaya ateş açıldı: 2 yara...
# ✓ Haber kaydedildi: TRT'ye üst kademe atamalar Resmi Gazete'de...
# ✓ Haber kaydedildi: Ankara'da 26 katlı binada yangın: 3 ölü...
# ✓ Haber kaydedildi: 4 sanığa ev hapsi kararı...
# ✓ Haber kaydedildi: Aşırı sıcaklara karşı sıcak çarpması uyarısı!...
# ✓ Haber kaydedildi: Evde yapabileceğiniz göbek eritme hareketleri!...
# ✓ Haber kaydedildi: Beyaz tişörtleri yeniden değerlendirin!...
# ✓ Haber kaydedildi: "Köpek yaşı" gerçekten yedi yıl mıdır?...
# ✓ Haber kaydedildi: Gaz kaçağında hayat kurtaran önlemler...
# ✓ Haber kaydedildi: İlk zeytin dalı buluşması...
# ✓ Haber kaydedildi: Eşinin öpüşmesini yorumladı...
# ✓ Haber kaydedildi: "Bazen delilik gerekiyor"...
# ✓ Haber kaydedildi: Eleştireni vatandaşlıktan çıkaracak...
# ✓ Haber kaydedildi: Sezon finali tanıtımı yayınlandı...
# ✓ Haber kaydedildi: Tatil sezonunu açtı...
# ✓ Haber kaydedildi: Baş başa deniz keyfi...
# ✓ Haber kaydedildi: Ayakta alkışlandı...
# ✓ Haber kaydedildi: İkinci çocuğuna hamile...
# ✓ Haber kaydedildi: İnternetsiz mesajlaşma uygulaması!...
# ✓ Haber kaydedildi: Sırbistan-Türkiye voleybol maçı ne zaman?...
# ✓ Haber kaydedildi: 15 Temmuz resmi tatil mi?...
# ✓ Haber kaydedildi: ATA AÖF yaz okulu kayıtları ne zaman başlıyor?...
# ✓ Haber kaydedildi: BEDAŞ ve AYEDAŞ duyurdu...
# ✓ Haber kaydedildi: Chelsea PSG maçı ne zaman?...
# ✓ Haber kaydedildi: Çay ve kahve, su ihtiyacını karşılar mı?...
# ✓ Haber kaydedildi: Bu beldede hayvan beslemek yasaklandı...
# ✓ Haber kaydedildi: Biricik Sevgilim filmi konusu nedir?...
# ✓ Haber kaydedildi: ÖGG sonuçları açıklanma tarihi 2025...
# ✓ Haber kaydedildi: Belediyenin "Grup Şantiye"si konsere hazırlanıyor...
# ✓ Haber kaydedildi: LGS birincisi kim oldu?...
# ✓ Haber kaydedildi: Rusya'daki az bilinen Türk halkı...
# ✓ Haber kaydedildi: "İzmir'deki orman yangınlarında yanan alan rekoru ...
# ✓ Haber kaydedildi: AÖF yaz okulu sınavı ne zaman?...
# ✓ Haber kaydedildi: Galatasaray-Ümraniyespor maçı ne zaman?...
# ✓ Haber kaydedildi: Spotify kapanacak mı?...
# ✓ Haber kaydedildi: Şanlıurfalı gönüllüden 63 bin fidan...
# ✓ Haber kaydedildi: Cumhurbaşkanı Erdoğan'a hediye edilen aslanların 3...
# ✓ Haber kaydedildi: A101 aktüel ürünler kataloğu 17 Temmuz 2025...
# ✓ Haber kaydedildi: Asgari ücrete ara zam var mı?...
# ✓ Haber kaydedildi: Temmuz ayında temettü veren şirketler...
# ✓ Haber kaydedildi: Rize'de kaza! Ölü ve yaralılar var...
# ntv kaynağından haberler çekiliyor...
# ✓ ntv - 100 haber bulundu
# ✓ Haber kaydedildi: Demokrasi ve Milli Birlik Günü'nün yıl dönümü önce...
# ✓ Haber kaydedildi: Sofia Vergara’ya memleketinden dev sürpriz: Heykel...
# ✓ Haber kaydedildi: Ankara'da 'fuhuş' operasyonu: 11 işyeri mühürlendi...
# ✓ Haber kaydedildi: Fransa'dan tarihi adım: 'Yeni Kaledonya Devleti' k...
# ✓ Haber kaydedildi: İstanbul'da toplu ulaşım 15 Temmuz'da ücretsiz ola...
# ✓ Haber kaydedildi: Nesli tehlike altında: 'Dumanlı Apollo' Uludağ'da ...
# ✓ Haber kaydedildi: IŞİD'in sosyal medya ekibi İstanbul'da çıktı: 3 tu...
# ✓ Haber kaydedildi: Vanessa Hudgens ikinci kez anne oluyor...
# ✓ Haber kaydedildi: MHP'de 'süreç' istifası: 'Artık kimseye verecek bi...
# ✓ Haber kaydedildi: Son Dakika... Ömer Çelik açıkladı... AKP, komisyon...
# ✓ Haber kaydedildi: Sezen Aksu 71 yaşında! Emel Müftüoğlu'ndan duygusa...
# ✓ Haber kaydedildi: Yaz aylarında içinizi serinleten pratik lezzet: Yo...
# ✓ Haber kaydedildi: Orkun Kökçü, sağlık kontrolünden geçti...
# ✓ Haber kaydedildi: MEB AGS soru kitapçığı yayımlandı mı? AGS ÖABT sor...
# ✓ Haber kaydedildi: Lionel Messi galibiyeti getirdi, rekorunu geliştir...
# ✓ Haber kaydedildi: Sivas Çandır köyünde siyanür havuzu tepkisi: 'Gözü...
# ✓ Haber kaydedildi: Bilimin ışığında yeniden doğuş ve etik sorular...
# ✓ Haber kaydedildi: Karşımızdakini oluşturmak...
# ✓ Haber kaydedildi: Ömer Seyfettin’in kızı: Güner Elgen...
# ✓ Haber kaydedildi: Kültür Rotası...
# ✓ Haber kaydedildi: Bir kadın kente tırmandığında...
# ✓ Haber kaydedildi: Zamlı emekli maaşı ne zaman yatacak? SSK, Bağ-Kur ...
# ✓ Haber kaydedildi: Can kaybı yok (mu?)...
# ✓ Haber kaydedildi: Artık lezzet de bir gösteri...
# ✓ Haber kaydedildi: Baksı: Çoruh'tan esen kültür rüzgarı...
# ✓ Haber kaydedildi: Muğla’da dehşet anları: Kadın turistleri tekme tok...
# ✓ Haber kaydedildi: Nietzsche’nin şen bilimi...
# ✓ Haber kaydedildi: Yiğit Bulut'un cenazesinde dikkat çeken görüntü: B...
# ✓ Haber kaydedildi: Manchester United'da Altay Bayındır gelişmesi!...
# ✓ Haber kaydedildi: İnsan Nedir?...
# ✓ Haber kaydedildi: Osayi-Samuel yeni takımıyla ilk maçına çıktı!...
# ✓ Haber kaydedildi: Okan Buruk'tan ayrılacak oyuncular için açıklama: ...
# ✓ Haber kaydedildi: Şile Belediyesi'ne operasyon: Başkan Özgür Kabaday...
# ✓ Haber kaydedildi: Ünlü sanatçı Ozan Doğulu dolandırıcıların hedefi o...
# ✓ Haber kaydedildi: Salih Müslim’den Şam yönetimine rest: Bu anayasayı...
# ✓ Haber kaydedildi: 3 yıl önce ekilmişti ilk hasadı başladı: Bölgedeki...
# ✓ Haber kaydedildi: İBB soruşturmasında tutuklanmıştı: Ramazan Gülten'...
